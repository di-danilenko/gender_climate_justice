# %%
import csv
import pandas as pd
import numpy as np
from sklearn.manifold import TSNE
from numpy import reshape
import seaborn as sns

# %%
dtm = pd.read_csv("DTM.csv")

# %%
display(dtm)
# Out:
#        Unnamed: 0  docnum    Topic1    Topic2    Topic3    Topic4    Topic5  \
# 0               1       1  0.000336  0.000485  0.000394  0.000510  0.000195
# 1               2       2  0.000167  0.001292  0.000604  0.000285  0.000025
# 2               3       3  0.000376  0.000198  0.000344  0.000823  0.000055
# 3               4       4  0.001108  0.000166  0.000406  0.001311  0.000730
# 4               5       5  0.000409  0.000099  0.000039  0.000064  0.000252
# ...           ...     ...       ...       ...       ...       ...       ...
# 42543       42544   42544  0.004089  0.000253  0.000177  0.002206  0.000133
# 42544       42545   42545  0.000480  0.000361  0.000194  0.000517  0.002535
# 42545       42546   42546  0.000304  0.000343  0.000097  0.000107  0.000029
# 42546       42547   42547  0.006488  0.000127  0.000065  0.000074  0.000021
# 42547       42548   42548  0.000263  0.000474  0.000086  0.000027  0.000344
#
#          Topic6    Topic7    Topic8  ...  Topic112  Topic113  Topic114  \
# 0      0.000264  0.000980  0.000204  ...  0.008732  0.009710  0.000201
# 1      0.001127  0.000114  0.013377  ...  0.005263  0.104050  0.000436
# 2      0.001650  0.000425  0.000544  ...  0.005800  0.001287  0.001152
# 3      0.001153  0.000110  0.001302  ...  0.004000  0.001217  0.000849
# 4      0.000829  0.000267  0.005635  ...  0.003280  0.000616  0.000088
# ...         ...       ...       ...  ...       ...       ...       ...
# 42543  0.000713  0.000753  0.001552  ...  0.004446  0.001138  0.001441
# 42544  0.000498  0.000045  0.001773  ...  0.004960  0.016416  0.000345
# 42545  0.001112  0.000173  0.001700  ...  0.004668  0.001067  0.008672
# 42546  0.000197  0.000170  0.000408  ...  0.002508  0.000916  0.000336
# 42547  0.000319  0.000082  0.003725  ...  0.007223  0.000819  0.000981
#
#        Topic115  Topic116  Topic117  Topic118  Topic119  Topic120     meta
# 0      0.017709  0.005965  0.000316  0.000193  0.055029  0.000935       20
# 1      0.015238  0.000202  0.000299  0.056658  0.007871  0.000898      108
# 2      0.002339  0.000393  0.000153  0.026729  0.044357  0.000972      157
# 3      0.001968  0.001846  0.000171  0.025166  0.086968  0.000802      195
# 4      0.011276  0.001012  0.000085  0.001305  0.005271  0.000403      222
# ...         ...       ...       ...       ...       ...       ...      ...
# 42543  0.006322  0.001032  0.000215  0.004742  0.028907  0.000872  5415254
# 42544  0.007435  0.001698  0.000448  0.050970  0.010608  0.000988  5415268
# 42545  0.003586  0.000218  0.000045  0.006744  0.002242  0.001053  5415341
# 42546  0.002833  0.000603  0.000045  0.050094  0.159710  0.000450  5415354
# 42547  0.003263  0.000873  0.000066  0.026519  0.008797  0.000725  5467024
#
# [42548 rows x 123 columns]

# %%
df = pd.read_csv("data/df_full.csv")

# %%
dtm.drop(['Unnamed: 0', 'docnum'], axis=1, inplace=True)

# %%
dtm['sum'] = np.nan

# %%
cols_to_search = [col for col in dtm.columns if col not in ['sum', 'meta']]
dtm['highestscoretopic'] = dtm[cols_to_search].idxmax(axis=1)
# now we'll have to group these by coordinates and choose a most common topic

# %%
climatejusticetopics = ["Topic12","Topic21","Topic25","Topic44","Topic50","Topic56","Topic80","Topic81","Topic83","Topic87","Topic89","Topic91","Topic101","Topic118","Topic119"]
dtm['sum'] = dtm[climatejusticetopics].sum(axis=1)

# %%
tsne = TSNE(n_components=2, verbose=1, random_state=7, angle=.99, init="pca")
cols_to_exclude = ['meta','sum','highestscoretopic']
# 100-D -> 2-D
tsne_results = tsne.fit_transform(dtm.loc[:, ~dtm.columns.isin(cols_to_exclude)]) 
# check that this array follows the same order as dtm rows
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 42548 samples in 0.008s...
# [t-SNE] Computed neighbors for 42548 samples in 53.321s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 42548
# [t-SNE] Computed conditional probabilities for sample 2000 / 42548
# [t-SNE] Computed conditional probabilities for sample 3000 / 42548
# [t-SNE] Computed conditional probabilities for sample 4000 / 42548
# [t-SNE] Computed conditional probabilities for sample 5000 / 42548
# [t-SNE] Computed conditional probabilities for sample 6000 / 42548
# [t-SNE] Computed conditional probabilities for sample 7000 / 42548
# [t-SNE] Computed conditional probabilities for sample 8000 / 42548
# [t-SNE] Computed conditional probabilities for sample 9000 / 42548
# [t-SNE] Computed conditional probabilities for sample 10000 / 42548
# [t-SNE] Computed conditional probabilities for sample 11000 / 42548
# [t-SNE] Computed conditional probabilities for sample 12000 / 42548
# [t-SNE] Computed conditional probabilities for sample 13000 / 42548
# [t-SNE] Computed conditional probabilities for sample 14000 / 42548
# [t-SNE] Computed conditional probabilities for sample 15000 / 42548
# [t-SNE] Computed conditional probabilities for sample 16000 / 42548
# [t-SNE] Computed conditional probabilities for sample 17000 / 42548
# [t-SNE] Computed conditional probabilities for sample 18000 / 42548
# [t-SNE] Computed conditional probabilities for sample 19000 / 42548
# [t-SNE] Computed conditional probabilities for sample 20000 / 42548
# [t-SNE] Computed conditional probabilities for sample 21000 / 42548
# [t-SNE] Computed conditional probabilities for sample 22000 / 42548
# [t-SNE] Computed conditional probabilities for sample 23000 / 42548
# [t-SNE] Computed conditional probabilities for sample 24000 / 42548
# [t-SNE] Computed conditional probabilities for sample 25000 / 42548
# [t-SNE] Computed conditional probabilities for sample 26000 / 42548
# [t-SNE] Computed conditional probabilities for sample 27000 / 42548
# [t-SNE] Computed conditional probabilities for sample 28000 / 42548
# [t-SNE] Computed conditional probabilities for sample 29000 / 42548
# [t-SNE] Computed conditional probabilities for sample 30000 / 42548
# [t-SNE] Computed conditional probabilities for sample 31000 / 42548
# [t-SNE] Computed conditional probabilities for sample 32000 / 42548
# [t-SNE] Computed conditional probabilities for sample 33000 / 42548
# [t-SNE] Computed conditional probabilities for sample 34000 / 42548
# [t-SNE] Computed conditional probabilities for sample 35000 / 42548
# [t-SNE] Computed conditional probabilities for sample 36000 / 42548
# [t-SNE] Computed conditional probabilities for sample 37000 / 42548
# [t-SNE] Computed conditional probabilities for sample 38000 / 42548
# [t-SNE] Computed conditional probabilities for sample 39000 / 42548
# [t-SNE] Computed conditional probabilities for sample 40000 / 42548
# [t-SNE] Computed conditional probabilities for sample 41000 / 42548
# [t-SNE] Computed conditional probabilities for sample 42000 / 42548
# [t-SNE] Computed conditional probabilities for sample 42548 / 42548
# [t-SNE] Mean sigma: 0.069888
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 107.074493
# [t-SNE] KL divergence after 1000 iterations: 3.011960

# %%
df1 = pd.DataFrame()
df1["id"] = dtm["meta"]
df1["comp-1"] = tsne_results[:,0]
df1["comp-2"] = tsne_results[:,1]
df1 = pd.merge(df1, df[["id","first_author_female","last_author_female","majority_female_binary"]], on="id", how='left')

# %%
dtm.rename(columns = {"meta":"id"}, inplace=True)
df1 = pd.merge(df1, dtm[["id","highestscoretopic","sum"]], on="id", how='left')
df1.rename(columns = {"highestscoretopic":"topic", "sum":"climatejusticescore"}, inplace=True)
display(df1)
# Out:
#             id     comp-1     comp-2 first_author_female last_author_female  \
# 0           20  -6.827012  43.530376             unknown            unknown
# 1          108  13.140246  20.787085                 1.0                0.0
# 2          157  32.998978  20.011883                 0.0                0.0
# 3          195  20.072718   5.684520                 1.0                1.0
# 4          222  -6.735416 -18.007849                 1.0                1.0
# ...        ...        ...        ...                 ...                ...
# 42543  5415254  10.971690  36.033791             unknown            unknown
# 42544  5415268  19.439703 -40.749409             unknown            unknown
# 42545  5415341   5.020032 -28.502401             unknown            unknown
# 42546  5415354  41.296196 -33.440475             unknown            unknown
# 42547  5467024  47.914425   7.323752             unknown            unknown
#
#       majority_female_binary     topic  climatejusticescore
# 0                    unknown   Topic68             0.090797
# 1                    unknown   Topic78             0.272802
# 2                        0.0   Topic91             0.440953
# 3                        1.0   Topic45             0.294310
# 4                        1.0  Topic108             0.045385
# ...                      ...       ...                  ...
# 42543                    0.0   Topic84             0.260547
# 42544                    0.0   Topic27             0.132807
# 42545                    0.5   Topic65             0.106981
# 42546                    0.0   Topic34             0.286833
# 42547                    0.0   Topic80             0.502964
#
# [42548 rows x 8 columns]

# %%
df1.to_csv("tsne.csv")

# %%
# Create the scatterplot with color based on "first_author_female" column
df1_filtered = df1[df1["first_author_female"] != "unknown"]
sns.scatterplot(x="comp-1", y="comp-2", hue="first_author_female", data=df1_filtered)
# Out:
# <AxesSubplot:xlabel='comp-1', ylabel='comp-2'>
