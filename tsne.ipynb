# %%
import csv
import pandas as pd
import numpy as np
from sklearn.manifold import TSNE
from numpy import reshape
import seaborn as sns

# %%
#dtm1 = pd.read_csv("DTM1.csv")
dtm2 = pd.read_csv("DTM2.csv")
dtm3 = pd.read_csv("DTM3.csv")

# %%
df_first = pd.read_csv("/Users/dianadanilenko/Desktop/methods/python_scripts/data/df_first_1804.csv")
df_last = pd.read_csv("/Users/dianadanilenko/Desktop/methods/python_scripts/data/df_last_1804.csv")
df_maj = pd.read_csv("/Users/dianadanilenko/Desktop/methods/python_scripts/data/df_maj_1804.csv")

# %%
dtm2.drop(['Unnamed: 0', 'docnum'], axis=1, inplace=True)

# %%
dtm3['sum'] = np.nan

# %%
cols_to_search2 = [col for col in dtm2.columns if col not in ['sum', 'meta']]
cols_to_search3 = [col for col in dtm3.columns if col not in ['sum', 'meta']]
#dtm1['highestscoretopic'] = dtm1[cols_to_search].idxmax(axis=1)
dtm2['highestscoretopic'] = dtm2[cols_to_search2].idxmax(axis=1)
dtm3['highestscoretopic'] = dtm3[cols_to_search3].idxmax(axis=1)
# now we'll have to group these by coordinates and choose a most common topic

# %%
#climatejusticetopics1 = ["Topic48","Topic33","Topic71","Topic35","Topic80","Topic51","Topic64"]
climatejusticetopics2 = ["Topic95","Topic33","Topic72","Topic91","Topic83","Topic51","Topic93","Topic64"]
climatejusticetopics3 = ["Topic79","Topic71","Topic50","Topic13","Topic20","Topic65","Topic86","Topic43"]
#dtm1['sum'] = dtm1[climatejusticetopics1].sum(axis=1)
dtm2['sum'] = dtm2[climatejusticetopics1].sum(axis=1)
dtm3['sum'] = dtm3[climatejusticetopics1].sum(axis=1)

# %%
display(dtm1)
# Out:
#          Topic1    Topic2    Topic3    Topic4    Topic5    Topic6    Topic7  \
# 0      0.001500  0.000212  0.004247  0.000167  0.002764  0.015367  0.010567
# 1      0.020526  0.002584  0.002520  0.000107  0.088972  0.000183  0.001384
# 2      0.001931  0.000277  0.002125  0.000200  0.003017  0.001478  0.003613
# 3      0.047843  0.000280  0.001047  0.000210  0.002297  0.003863  0.004918
# 4      0.153474  0.000277  0.001399  0.000021  0.003233  0.001281  0.010351
# ...         ...       ...       ...       ...       ...       ...       ...
# 31417  0.000916  0.000910  0.000904  0.001086  0.006131  0.002216  0.004779
# 31418  0.001493  0.001024  0.002873  0.000541  0.003686  0.029670  0.003996
# 31419  0.001416  0.000311  0.005276  0.000627  0.003650  0.002105  0.002704
# 31420  0.001285  0.000803  0.002491  0.000222  0.028963  0.003586  0.017938
# 31421  0.006748  0.000210  0.000641  0.000991  0.000690  0.002748  0.039940
#
#          Topic8    Topic9   Topic10  ...   Topic84   Topic85   Topic86  \
# 0      0.002263  0.018171  0.000837  ...  0.001158  0.000302  0.001682
# 1      0.001781  0.045429  0.000564  ...  0.001554  0.000455  0.004578
# 2      0.001091  0.053185  0.001100  ...  0.005288  0.001425  0.001404
# 3      0.000281  0.072479  0.004699  ...  0.000979  0.000071  0.000202
# 4      0.000932  0.030139  0.000662  ...  0.000879  0.000329  0.001257
# ...         ...       ...       ...  ...       ...       ...       ...
# 31417  0.001314  0.072372  0.000614  ...  0.001392  0.000306  0.012793
# 31418  0.000441  0.039887  0.001558  ...  0.001475  0.003816  0.002090
# 31419  0.000149  0.119281  0.000436  ...  0.000315  0.000652  0.001791
# 31420  0.002210  0.028981  0.003124  ...  0.001484  0.000245  0.000079
# 31421  0.001109  0.206661  0.000262  ...  0.000797  0.000105  0.000080
#
#         Topic87   Topic88   Topic89   Topic90   meta       sum  \
# 0      0.001470  0.088008  0.001880  0.001690    157  0.342935
# 1      0.000150  0.001669  0.001465  0.000906    300  0.009175
# 2      0.000663  0.018758  0.001853  0.002788    332  0.107349
# 3      0.000686  0.051839  0.001412  0.001700    694  0.193290
# 4      0.000374  0.023124  0.000615  0.002131    880  0.093375
# ...         ...       ...       ...       ...    ...       ...
# 31417  0.004646  0.006318  0.031978  0.002684  98435  0.211939
# 31418  0.000968  0.013375  0.014430  0.002984  98471  0.202991
# 31419  0.000862  0.003717  0.007207  0.002328  99032  0.557903
# 31420  0.048132  0.023918  0.001941  0.003764  99515  0.062321
# 31421  0.162939  0.017523  0.002073  0.001652  99548  0.061759
#
#        highestscoretopic
# 0                Topic48
# 1                Topic62
# 2                Topic78
# 3                Topic55
# 4                 Topic1
# ...                  ...
# 31417            Topic21
# 31418            Topic64
# 31419            Topic33
# 31420            Topic24
# 31421             Topic9
#
# [31422 rows x 93 columns]

# %%
tsne = TSNE(n_components=2, verbose=1, random_state=7, angle=.99, init="pca")
cols_to_exclude = ['meta','sum','highestscoretopic']
# 100-D -> 2-D
tsne_results1 = tsne.fit_transform(dtm1.loc[:, ~dtm1.columns.isin(cols_to_exclude)]) 
# check that this array follows the same order as dtm rows
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 31422 samples in 0.004s...
# [t-SNE] Computed neighbors for 31422 samples in 23.844s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 31422
# [t-SNE] Computed conditional probabilities for sample 2000 / 31422
# [t-SNE] Computed conditional probabilities for sample 3000 / 31422
# [t-SNE] Computed conditional probabilities for sample 4000 / 31422
# [t-SNE] Computed conditional probabilities for sample 5000 / 31422
# [t-SNE] Computed conditional probabilities for sample 6000 / 31422
# [t-SNE] Computed conditional probabilities for sample 7000 / 31422
# [t-SNE] Computed conditional probabilities for sample 8000 / 31422
# [t-SNE] Computed conditional probabilities for sample 9000 / 31422
# [t-SNE] Computed conditional probabilities for sample 10000 / 31422
# [t-SNE] Computed conditional probabilities for sample 11000 / 31422
# [t-SNE] Computed conditional probabilities for sample 12000 / 31422
# [t-SNE] Computed conditional probabilities for sample 13000 / 31422
# [t-SNE] Computed conditional probabilities for sample 14000 / 31422
# [t-SNE] Computed conditional probabilities for sample 15000 / 31422
# [t-SNE] Computed conditional probabilities for sample 16000 / 31422
# [t-SNE] Computed conditional probabilities for sample 17000 / 31422
# [t-SNE] Computed conditional probabilities for sample 18000 / 31422
# [t-SNE] Computed conditional probabilities for sample 19000 / 31422
# [t-SNE] Computed conditional probabilities for sample 20000 / 31422
# [t-SNE] Computed conditional probabilities for sample 21000 / 31422
# [t-SNE] Computed conditional probabilities for sample 22000 / 31422
# [t-SNE] Computed conditional probabilities for sample 23000 / 31422
# [t-SNE] Computed conditional probabilities for sample 24000 / 31422
# [t-SNE] Computed conditional probabilities for sample 25000 / 31422
# [t-SNE] Computed conditional probabilities for sample 26000 / 31422
# [t-SNE] Computed conditional probabilities for sample 27000 / 31422
# [t-SNE] Computed conditional probabilities for sample 28000 / 31422
# [t-SNE] Computed conditional probabilities for sample 29000 / 31422
# [t-SNE] Computed conditional probabilities for sample 30000 / 31422
# [t-SNE] Computed conditional probabilities for sample 31000 / 31422
# [t-SNE] Computed conditional probabilities for sample 31422 / 31422
# [t-SNE] Mean sigma: 0.070150
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 103.218369
# [t-SNE] KL divergence after 1000 iterations: 2.728350

# %%
tsne_results2 = tsne.fit_transform(dtm2.loc[:, ~dtm2.columns.isin(cols_to_exclude)]) 
tsne_results3 = tsne.fit_transform(dtm3.loc[:, ~dtm3.columns.isin(cols_to_exclude)])
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 32873 samples in 0.002s...
# [t-SNE] Computed neighbors for 32873 samples in 19.042s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 32873
# [t-SNE] Computed conditional probabilities for sample 2000 / 32873
# [t-SNE] Computed conditional probabilities for sample 3000 / 32873
# [t-SNE] Computed conditional probabilities for sample 4000 / 32873
# [t-SNE] Computed conditional probabilities for sample 5000 / 32873
# [t-SNE] Computed conditional probabilities for sample 6000 / 32873
# [t-SNE] Computed conditional probabilities for sample 7000 / 32873
# [t-SNE] Computed conditional probabilities for sample 8000 / 32873
# [t-SNE] Computed conditional probabilities for sample 9000 / 32873
# [t-SNE] Computed conditional probabilities for sample 10000 / 32873
# [t-SNE] Computed conditional probabilities for sample 11000 / 32873
# [t-SNE] Computed conditional probabilities for sample 12000 / 32873
# [t-SNE] Computed conditional probabilities for sample 13000 / 32873
# [t-SNE] Computed conditional probabilities for sample 14000 / 32873
# [t-SNE] Computed conditional probabilities for sample 15000 / 32873
# [t-SNE] Computed conditional probabilities for sample 16000 / 32873
# [t-SNE] Computed conditional probabilities for sample 17000 / 32873
# [t-SNE] Computed conditional probabilities for sample 18000 / 32873
# [t-SNE] Computed conditional probabilities for sample 19000 / 32873
# [t-SNE] Computed conditional probabilities for sample 20000 / 32873
# [t-SNE] Computed conditional probabilities for sample 21000 / 32873
# [t-SNE] Computed conditional probabilities for sample 22000 / 32873
# [t-SNE] Computed conditional probabilities for sample 23000 / 32873
# [t-SNE] Computed conditional probabilities for sample 24000 / 32873
# [t-SNE] Computed conditional probabilities for sample 25000 / 32873
# [t-SNE] Computed conditional probabilities for sample 26000 / 32873
# [t-SNE] Computed conditional probabilities for sample 27000 / 32873
# [t-SNE] Computed conditional probabilities for sample 28000 / 32873
# [t-SNE] Computed conditional probabilities for sample 29000 / 32873
# [t-SNE] Computed conditional probabilities for sample 30000 / 32873
# [t-SNE] Computed conditional probabilities for sample 31000 / 32873
# [t-SNE] Computed conditional probabilities for sample 32000 / 32873
# [t-SNE] Computed conditional probabilities for sample 32873 / 32873
# [t-SNE] Mean sigma: 0.070543
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 103.741776
# [t-SNE] KL divergence after 1000 iterations: 2.800651
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 22266 samples in 0.001s...
# [t-SNE] Computed neighbors for 22266 samples in 9.251s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 22266
# [t-SNE] Computed conditional probabilities for sample 2000 / 22266
# [t-SNE] Computed conditional probabilities for sample 3000 / 22266
# [t-SNE] Computed conditional probabilities for sample 4000 / 22266
# [t-SNE] Computed conditional probabilities for sample 5000 / 22266
# [t-SNE] Computed conditional probabilities for sample 6000 / 22266
# [t-SNE] Computed conditional probabilities for sample 7000 / 22266
# [t-SNE] Computed conditional probabilities for sample 8000 / 22266
# [t-SNE] Computed conditional probabilities for sample 9000 / 22266
# [t-SNE] Computed conditional probabilities for sample 10000 / 22266
# [t-SNE] Computed conditional probabilities for sample 11000 / 22266
# [t-SNE] Computed conditional probabilities for sample 12000 / 22266
# [t-SNE] Computed conditional probabilities for sample 13000 / 22266
# [t-SNE] Computed conditional probabilities for sample 14000 / 22266
# [t-SNE] Computed conditional probabilities for sample 15000 / 22266
# [t-SNE] Computed conditional probabilities for sample 16000 / 22266
# [t-SNE] Computed conditional probabilities for sample 17000 / 22266
# [t-SNE] Computed conditional probabilities for sample 18000 / 22266
# [t-SNE] Computed conditional probabilities for sample 19000 / 22266
# [t-SNE] Computed conditional probabilities for sample 20000 / 22266
# [t-SNE] Computed conditional probabilities for sample 21000 / 22266
# [t-SNE] Computed conditional probabilities for sample 22000 / 22266
# [t-SNE] Computed conditional probabilities for sample 22266 / 22266
# [t-SNE] Mean sigma: 0.071380
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 100.031433
# [t-SNE] KL divergence after 1000 iterations: 2.562141

# %%
display(tsne_results3)
# Out:
# array([[  2.367215 ,  -5.1932216],
#        [-13.431983 , -54.65523  ],
#        [ 16.1537   , -16.996185 ],
#        ...,
#        [ 14.820707 ,  24.98012  ],
#        [-11.51479  , -40.91162  ],
#        [ -1.8391073,  37.963074 ]], dtype=float32)

# %%
df1 = pd.DataFrame()
df1["id"] = dtm1["meta"]
df1["comp-1"] = tsne_results1[:,0]
df1["comp-2"] = tsne_results1[:,1]
df1 = pd.merge(df1, df_first[["id","first_author_female"]], on="id", how='left')

# %%
df2 = pd.DataFrame()
df2["id"] = dtm2["meta"]
df2["comp-1"] = tsne_results2[:,0]
df2["comp-2"] = tsne_results2[:,1]
df2 = pd.merge(df2, df_last[["id","last_author_female"]], on="id", how='left')

# %%
df3 = pd.DataFrame()
df3["id"] = dtm3["meta"]
df3["comp-1"] = tsne_results3[:,0]
df3["comp-2"] = tsne_results3[:,1]
df3 = pd.merge(df3, df_maj[["id","majority_female_binary"]], on="id", how='left')

# %%
dtm1.rename(columns = {"meta":"id"}, inplace=True)
df1 = pd.merge(df1, dtm1[["id","highestscoretopic","sum"]], on="id", how='left')
df1.rename(columns = {"highestscoretopic":"topic", "sum":"climatejusticescore"}, inplace=True)
display(df1)
# Out:
#           id     comp-1     comp-2  first_author_female    topic  \
# 0        157  52.550190  13.704720                  0.0  Topic48
# 1        300 -21.306911 -23.298317                  0.0  Topic62
# 2        332  -2.871118   8.239209                  1.0  Topic78
# 3        694  25.785948  11.473897                  1.0  Topic55
# 4        880  25.115221 -29.070986                  0.0   Topic1
# ...      ...        ...        ...                  ...      ...
# 31417  98435  31.329865 -28.850069                  0.0  Topic21
# 31418  98471  -6.011520   4.903882                  0.0  Topic64
# 31419  99032  23.377766 -21.605757                  1.0  Topic33
# 31420  99515  20.373291 -46.996990                  0.0  Topic24
# 31421  99548  46.881126 -13.639525                  1.0   Topic9
#
#        climatejusticescore
# 0                 0.342935
# 1                 0.009175
# 2                 0.107349
# 3                 0.193290
# 4                 0.093375
# ...                    ...
# 31417             0.211939
# 31418             0.202991
# 31419             0.557903
# 31420             0.062321
# 31421             0.061759
#
# [31422 rows x 6 columns]

# %%
dtm2.rename(columns = {"meta":"id"}, inplace=True)
df2 = pd.merge(df2, dtm2[["id","highestscoretopic","sum"]], on="id", how='left')
df2.rename(columns = {"highestscoretopic":"topic", "sum":"climatejusticescore"}, inplace=True)

dtm3.rename(columns = {"meta":"id"}, inplace=True)
df3 = pd.merge(df3, dtm3[["id","highestscoretopic","sum"]], on="id", how='left')
df3.rename(columns = {"highestscoretopic":"topic", "sum":"climatejusticescore"}, inplace=True)

# %%
#df1.to_csv("tsne1.csv")
df2.to_csv("tsne2.csv")
df3.to_csv("tsne3.csv")

# %%
sns.scatterplot(x="comp-1", y="comp-2", hue=df.y.tolist(),
                data=df).set(title="t-SNE visualisation of STM")
# Out:
# [Text(0.5, 1.0, 'T-SNE visualisation of STM')]

# %%
sns.scatterplot(x="comp-1", y="comp-2", hue=df.y.tolist(),
                palette=sns.color_palette("hls", len(df["y"])),
                data=df).set(title="T-SNE visualisation of STM")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-88990c38e19a> in <module>
# ----> 1 sns.scatterplot(x="comp-1", y="comp-2", hue=df.y.tolist(),
#       2                 palette=sns.color_palette("hls", len(df["y"])),
#       3                 data=df).set(title="T-SNE visualisation of STM")
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#     818     p._attach(ax)
#     819
# --> 820     p.plot(ax, kwargs)
#     821
#     822     return ax
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/relational.py in plot(self, ax, kws)
#     661         self._add_axis_labels(ax)
#     662         if self.legend:
# --> 663             self.add_legend_data(ax)
#     664             handles, _ = ax.get_legend_handles_labels()
#     665             if handles:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/relational.py in add_legend_data(self, ax)
#     335                 if attr in kws:
#     336                     use_kws[attr] = kws[attr]
# --> 337             artist = func([], [], label=label, **use_kws)
#     338             if self._legend_func == "plot":
#     339                 artist = artist[0]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/cbook/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4515                 self.set_ymargin(0.05)
#    4516
# -> 4517         self.add_collection(collection)
#    4518         self._request_autoscale_view()
#    4519
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py in add_collection(self, collection, autolim)
#    1932             # Make sure viewLim is not stale (mostly to match
#    1933             # pre-lazy-autoscale behavior, which is not really better).
# -> 1934             self._unstale_viewLim()
#    1935             self.update_datalim(collection.get_datalim(self.transData))
#    1936
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py in _unstale_viewLim(self)
#     645             for ax in self._shared_y_axes.get_siblings(self):
#     646                 ax._stale_viewlim_y = False
# --> 647             self.autoscale_view(scalex=scalex, scaley=scaley)
#     648
#     649     @property
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py in autoscale_view(self, tight, scalex, scaley)
#    2500                     for artist in ax.get_children()]))
#    2501             if self._ymargin and scaley and self._autoscaleYon:
# -> 2502                 y_stickies = np.sort(np.concatenate([
#    2503                     artist.sticky_edges.y
#    2504                     for ax in self._shared_y_axes.get_siblings(self)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py in <listcomp>(.0)
#    2501             if self._ymargin and scaley and self._autoscaleYon:
#    2502                 y_stickies = np.sort(np.concatenate([
# -> 2503                     artist.sticky_edges.y
#    2504                     for ax in self._shared_y_axes.get_siblings(self)
#    2505                     if hasattr(ax, "lines")
#
# KeyboardInterrupt:
# Error in callback <function flush_figures at 0x7fbfd1c55310> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/ipykernel/pylab/backend_inline.py in flush_figures()
#     119         # ignore the tracking, just draw and close all figures
#     120         try:
# --> 121             return show(True)
#     122         except Exception as e:
#     123             # safely show traceback if in IPython, else raise
#
# ~/opt/anaconda3/lib/python3.8/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      39     try:
#      40         for figure_manager in Gcf.get_all_fig_managers():
# ---> 41             display(
#      42                 figure_manager.canvas.figure,
#      43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     311             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     312         else:
# --> 313             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     314             if not format_dict:
#     315                 # nothing to display (e.g. _ipython_display_ took over)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# ~/opt/anaconda3/lib/python3.8/site-packages/decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2191                            else suppress())
#    2192                     with ctx:
# -> 2193                         self.figure.draw(renderer)
#    2194
#    2195                     bbox_inches = self.figure.get_tightbbox(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1861
#    1862             self.patch.draw(renderer)
# -> 1863             mimage._draw_list_compositing_images(
#    1864                 renderer, self, artists, self.suppressComposite)
#    1865
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/cbook/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2745             renderer.stop_rasterizing()
#    2746
# -> 2747         mimage._draw_list_compositing_images(renderer, self, artists)
#    2748
#    2749         renderer.close_group('axes')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/collections.py in draw(self, renderer)
#     929     def draw(self, renderer):
#     930         self.set_sizes(self._sizes, self.figure.dpi)
# --> 931         Collection.draw(self, renderer)
#     932
#     933
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/collections.py in draw(self, renderer)
#     383             else:
#     384                 combined_transform = transform
# --> 385             extents = paths[0].get_extents(combined_transform)
#     386             if (extents.width < self.figure.bbox.width
#     387                     and extents.height < self.figure.bbox.height):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/path.py in get_extents(self, transform, **kwargs)
#     597             for curve, code in self.iter_bezier(**kwargs):
#     598                 # places where the derivative is zero can be extrema
# --> 599                 _, dzeros = curve.axis_aligned_extrema()
#     600                 # as can the ends of the curve
#     601                 xys.append(curve([0, *dzeros, 1]))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/bezier.py in axis_aligned_extrema(self)
#     296         roots = []
#     297         for i, pi in enumerate(dCj.T):
# --> 298             r = np.roots(pi[::-1])
#     299             roots.append(r)
#     300             dims.append(np.full_like(r, i))
#
# <__array_function__ internals> in roots(*args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/lib/polynomial.py in roots(p)
#     251     if N > 1:
#     252         # build companion matrix and find its eigenvalues (the roots)
# --> 253         A = diag(NX.ones((N-2,), p.dtype), -1)
#     254         A[0,:] = -p[1:] / p[0]
#     255         roots = eigvals(A)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/core/numeric.py in ones(shape, dtype, order, like)
#     202
#     203     a = empty(shape, dtype, order)
# --> 204     multiarray.copyto(a, 1, casting='unsafe')
#     205     return a
#     206
#
# <__array_function__ internals> in copyto(*args, **kwargs)
#
# KeyboardInterrupt:
